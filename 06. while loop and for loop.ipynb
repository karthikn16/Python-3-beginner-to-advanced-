# %%
#while loop

a = 1
while a <=6:
  a = a+1
  print("karthi")
# Out:
# karthi
# karthi
# karthi
# karthi
# karthi
# karthi

# %%
#for loop

color = ["red" ,"green","orange"]
for a in color:
   print(a)
# Out:
# red
# green
# orange

# %%
#looping in for loop

for b in red:
  print(b)
# Out:
# o
# r
# a
# n
# g
# e

# %%
#break in for loop
color = ["red" ,"green","orange"]
for b in color:
   print(b)
   if b == "green":
     break
# Out:
# red
# green
