# %%
#arithmetic operator

a = 2
b = 3
print (a+b)
# Out:
# 5

# %%
c = 4
d = 2
print(c-d)
# Out:
# 2

# %%
e = 5
f = 2
print(e/f)
# Out:
# 2.5

# %%
g = 8
h = 5
print(g%h)
# Out:
# 3

# %%
i = 7
k = 8
print(i**k)
# Out:
# 5764801

# %%
l = 8
m = 9
print(l//m)
# Out:
# 0

# %%
#assignment operator

a += 10 
print(a)
# Out:
# 12

# %%
b -= 3
print(b)
# Out:
# 0

# %%
#comparison operator

s = 10
t = 10
print(s==t)
# Out:
# True

# %%
u = 9
v = 2
print(u != v)
# Out:
# True

# %%
#logical operator

y = 7
z = 9
print (y > 3 and u <10 )
print (z > 3 or v < 1)
print (not z > 3 and u < 9)
# Out:
# True
# True
# False
