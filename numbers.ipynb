# %%
#python numbers

#convert int to float

a = float(2)
print(a)
print(type(a))
# Out:
# 2.0
# <class 'float'>

# %%
#convert float to int

c = int(3.7)
print(c)
print(type(c))
# Out:
# 3
# <class 'int'>

# %%
#convert int to complex

d = complex(7)
print(d)
print(type(d))
# Out:
# (7+0j)
# <class 'complex'>

# %%
#random number

import random 
print(random.randrange(1, 10))
# Out:
# 8
